# %% [markdown]
# # AULA 6

# %% [markdown]
# ## LAÇOS DE COMPETIÇÃO

# %%
frutas = ["maçã", "banana", "cereja", "abacate","pera"]
for fruta in frutas:
    print(fruta)
# Out:
# maçã
# banana
# cereja
# abacate
# pera

# %%
for indice in range(5):
    print(f"indice: {indice} - Posição: {indice+1}")
# Out:
# indice: 0 - Posição: 1
# indice: 1 - Posição: 2
# indice: 2 - Posição: 3
# indice: 3 - Posição: 4
# indice: 4 - Posição: 5

# %%
contador=0
while (contador<5):
    print(contador)
    contador += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i=0
while (i<5):
    print(1)
    i += 1
# Out:
# 1
# 1
# 1
# 1
# 1

# %%
matriz=[
    [1,2,3],
    [4,5,6],
    [7,8,9],
    ["banana", "laranja", "beterraba"],
    [0.10, 0.06, 0.55]
]

for linha in matriz:
    for elemento in linha:
        print(elemento, end="\t")
    print()
# Out:
# 1	2	3
# 4	5	6
# 7	8	9
# banana	laranja	beterraba
# 0.1	0.06	0.55

# %%
for i in range(5):
    if i==5:
        break
    if i %2==0:
        continue
    print(i)
# Out:
# 1
# 3

# %%
for i in range(3):
    print(i)
else:
    print("Loop Concluido!")
# Out:
# 0
# 1
# 2
# Loop Concluido!

# %% [markdown]
# # Aula 04

# %% [markdown]
# ## 1a Atividade

# %%
meu_livro = "python para iniciantes"
print(meu_livro)
# Out:
# python para iniciantes

# %%
meu_livro = "Algoritmos divertidos"
print(meu_livro)
# Out:
# Algoritmos divertidos

# %%
PI = 3.14159
GRAVIDADE = 9.8

# %%
print (PI + GRAVIDADE)
# Out:
# 12.941590000000001

# %% [markdown]
# ## Desafio

# %%
nome = input ("Digite seu nome: ")
data_de_nasc = input ("Ano de nascimento: ")
data_de_nasc_int=int(data_de_nasc)
idade = (2026-data_de_nasc_int)

print(f"{nome}, sua idade é {idade} anos.")
# Out:
# Hugo, sua idade é 22 anos.

# %% [markdown]
# ## Tipos de dados

# %%
inteiro = 10
ponto_flutuante = 3.14
numero_complexo = 2 + 3j

# %%
print(type(inteiro))
print(type(ponto_flutuante))
print(type(numero_complexo))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# #### Testando as strings

# %%
nome="Hugo"

# %%
cep="25720-180"

# %%
logradouro="""Av. dos Paulistas
Bairro: Correas
Cidade: Petrópolis
Estado: RJ"""

# %%
print(nome)
# Out:
# Hugo

# %%
print(cep)
# Out:
# 25720-180

# %%
print(logradouro)
# Out:
# Av. dos Paulistas
# Bairro: Correas
# Cidade: Petrópolis
# Estado: RJ

# %% [markdown]
# #### Variáveis Booleanas

# %%
numero1=5
numero2=7

# %%
resultado=numero1 > numero2

# %%
resultado2=numero1 < numero2

# %%
print(resultado)
# Out:
# False

# %%
print(resultado2)
# Out:
# True

# %% [markdown]
# #### Listas - Tuplas e Ranges

# %%
tupla=(1, 2)
type(tupla)
# Out:
# tuple

# %%
lista=[1, 2]
type(lista)
# Out:
# list

# %%
print(tupla[1])
# Out:
# 2

# %%
print(lista)
# Out:
# {1, 2}

# %%
tupla[1] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 tupla[1] = 3
#
# TypeError: 'tuple' object does not support item assignment

# %%
lista[1]=3

# %%
print(lista)
# Out:
# [1, 3]

# %%
lista.append(4)
lista.append(5)

# %%
print(lista)
# Out:
# [1, 3, 4, 5]

# %%
lista = list(range(1, 10, 2))
print(lista)
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# ## Estruturas Condicionais

# %%
nome = input ("Digite seu nome: ")
ano_nasc = int(input(f"{nome}, digite o de nascimento: "))

# %%
idade = (2026 - ano_nasc)
idade=22

# %%
if idade >= 18:
    print(f"{nome}, você é maior de idade.")
elif idade >= 16:
    print(f"{nome}, você é adolescente.")
else:
    print(f"{nome}, você é menor de idade.")
# Out:
# Hugo, você é maior de idade.

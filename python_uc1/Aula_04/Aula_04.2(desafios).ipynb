# %% [markdown]
# # DESAFIO 3

# %% [markdown]
# ### 1 CALCULADORA BÁSICA

# %%
n1=int(input("Digite o primeiro número: "))
n2=int(input("Digite o segundo número: "))
soma=n1+n2
subtração=n1-n2
multiplicação=n1*n2
divisão=n1/n2

# %%
print(f"a soma entre {n1} e {n2} é: {soma}")
# Out:
# a soma entre 10 e 10 é: 20

# %%
print(f" a subtração entre {n1} e {n2} é: {subtração}")
# Out:
#  a subtração entre 10 e 10 é: 0

# %%
print(f" a multiplicação entre {n1} e {n2} é: {multiplicação}")
# Out:
#  a multiplicação entre 10 e 10 é: 100

# %%
print(f" a divisão entre {n1} e {n2} é {multiplicação}")
# Out:
#  a divisão entre 10 e 10 é 100

# %%
nota1=float(input("Digite a primeira nota"))
nota2=float(input("Digite a segunda nota"))
nota3=float(input("Digite a terceira nota"))

# %%
media=(nota1 + nota2 + nota3)/3

# %%
print(f"a média do aluno é: {media}")
# Out:
# a média do aluno é: 10.0

# %%
celsius=float(input("Digite a temperatura"))

# %%
f=(celsius*9/5)+32

# %%
print(f" A temperatura FAHRENHEIT correspondente é: {f}")
# Out:
#  A temperatura FAHRENHEIT correspondente é: 68.0

# %%
raio=float(input("Digite o raio do círculo"))

# %%
area=(3.14*raio**2)

# %%
print(f" A area do circulo é: {area}")
# Out:
#  A area do circulo é: 6358.5

# %%
peso=float(input("Digite seu peso em KG"))
altura=float(input("Digite sua altura em METROS"))

# %%
IMC=(peso/altura**2)

# %%
print(f" O seu IMC é: {IMC}")
# Out:
#  O seu IMC é: 26.22222222222222

# %%
total_compra=float(input("Digite o valor total da compra"))
desconto=(total_compra*0.10)

# %%
compra_desconto=(total_compra-desconto)

# %%
print(f" o valor da compra com desconto é: {compra_desconto}")
# Out:
#  o valor da compra com desconto é: 90.0

# %%
distancia=float(input("Digite a distância em KM"))
vm=float(input("Digite a velocidade média em KM/h"))

# %%
tempo=(distancia/vm)

# %%
print(f" O tempo necessário para chegar ao destino é: {tempo}")
# Out:
#  O tempo necessário para chegar ao destino é: 3.3333333333333335

# %%
valor_inicial=float(input("Digite o valor do investimento inicial"))
tx_juros=float(input("Digite o valor da taxa de jutos"))
tempo=float(input("Digite o tempo"))

# %%
montante=

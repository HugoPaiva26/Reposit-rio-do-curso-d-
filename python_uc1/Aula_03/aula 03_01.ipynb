# %% [markdown]
# # Aula 03 - Variáveis

# %% [markdown]
# ## Olá, mundo!

# %%
print ("Olá, mundo!")
# Out:
# Olá, mundo!

# %% [markdown]
# ## Tipos de variáveies

# %%
numero=19
numero_frac=15,2
texto="Flamengo"

# %%
type(numero)
# Out:
# int

# %%
type(texto)
# Out:
# str

# %%
type(numero_frac)
# Out:
# tuple

# %%
print(numero, numero_frac, texto)
# Out:
# 19 (15, 2) Flamengo

# %%
print(type(numero))
print(type(numero_frac))
print(type(texto))
# Out:
# <class 'int'>
# <class 'tuple'>
# <class 'str'>

# %%
texto.upper()
# Out:
# 'FLAMENGO'

# %%
numero_frac=15.2
type(numero_frac)
# Out:
# float

# %%
numero+numero_frac
# Out:
# 34.2

# %%
numero*texto
# Out:
# 'FlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengo'

# %%
texto2=texto+" "

# %%
texto2*numero
# Out:
# 'FlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengoFlamengo'

# %%
texto2=texto+" "+texto
print(texto2)
# Out:
# Flamengo Flamengo

# %%
idade=input("Digite sua idade")

# %%
type(idade)
# Out:
# str

# %%
idade=int(input("Informe sua idade"))

# %%
idade_num=float(idade)

# %%
type(idade-num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 type(idade-num)
#
# NameError: name 'num' is not defined
